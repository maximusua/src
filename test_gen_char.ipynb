# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
from keras.utils import plot_model
import pydot
import numpy as np
import random
import sys
import codecs

file_path = 'linux_simple.txt'
text = codecs.open(file_path, "r", "ISO-8859-1").read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 70
step = 1
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(None, len(chars)), return_sequences=False))
model.add(Dropout(0.2))
#model.add(LSTM(len(chars)))

model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 150):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=128,
              epochs=1)
    
   
    #plot_model(model, to_file='model.png')


    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.5, 1, 1.5]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(1000):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = np.argmax(preds)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# corpus length: 19420
# total chars: 65
# nb sequences: 19350
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 19350/19350 [==============================] - 70s - loss: 2.7329
#
# ----- diversity: 0.5
# ----- Generating with seed: "u_head_on_stack(struct rcu_head *head)
# {
# 	debug_object_free(head, &rcu"
# u_head_on_stack(struct rcu_head *head)
# {
# 	debug_object_free(head, &rcu_expoidedeadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readere
#
# ----- diversity: 1
# ----- Generating with seed: "u_head_on_stack(struct rcu_head *head)
# {
# 	debug_object_free(head, &rcu"
# u_head_on_stack(struct rcu_head *head)
# {
# 	debug_object_free(head, &rcu_expoidedeadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readere
#
# ----- diversity: 1.5
# ----- Generating with seed: "u_head_on_stack(struct rcu_head *head)
# {
# 	debug_object_free(head, &rcu"
# u_head_on_stack(struct rcu_head *head)
# {
# 	debug_object_free(head, &rcu_expoidedeadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readereadelock_readere
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 19350/19350 [==============================] - 69s - loss: 1.7864
#
# ----- diversity: 0.5
# ----- Generating with seed: ";
#
# #endif
#
# #ifdef config_tasks_rcu
#
#
#
#
# static struct rcu_head *rcu_ta"
# ;
#
# #endif
#
# #ifdef config_tasks_rcu
#
#
#
#
# static struct rcu_head *rcu_tasks_col_test_on_tercu_test_counterg = 0;
#
#
# ----- diversity: 1
# ----- Generating with seed: ";
#
# #endif
#
# #ifdef config_tasks_rcu
#
#
#
#
# static struct rcu_head *rcu_ta"
# ;
#
# #endif
#
# #ifdef config_tasks_rcu
#
#
#
#
# static struct rcu_head *rcu_tasks_col_test_on_tercu_test_counterg = 0;
#
#
# ----- diversity: 1.5
# ----- Generating with seed: ";
#
# #endif
#
# #ifdef config_tasks_rcu
#
#
#
#
# static struct rcu_head *rcu_ta"
# ;
#
# #endif
#
# #ifdef config_tasks_rcu
#
#
#
#
# static struct rcu_head *rcu_tasks_col_test_on_tercu_test_counterg = 0;
#
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 19350/19350 [==============================] - 68s - loss: 1.3949
#
# ----- diversity: 0.5
# ----- Generating with seed: "ched, bool, 0444);
#
# static int rcu_self_test_counter;
#
# static void tes"
# ched, bool, 0444);
#
# static int rcu_self_test_counter;
#
# static void teststing = 0;
#
#
# ----- diversity: 1
# ----- Generating with seed: "ched, bool, 0444);
#
# static int rcu_self_test_counter;
#
# static void tes"
# ched, bool, 0444);
#
# static int rcu_self_test_counter;
#
# static void teststing = 0;
#
#
# ----- diversity: 1.5
# ----- Generating with seed: "ched, bool, 0444);
#
# static int rcu_self_test_counter;
#
# static void tes"
# ched, bool, 0444);
#
# static int rcu_self_test_counter;
#
# static void teststing = 0;
#
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 19350/19350 [==============================] - 67s - loss: 1.1770
#
# ----- diversity: 0.5
# ----- Generating with seed: "eduler_active,
# 			   "synchronize_rcu_tasks called too soon");
#
#
# 	wai"
# eduler_active,
# 			   "synchronize_rcu_tasks called too soon");
#
#
# 	wait_rcu_head *head);
#
#
# ----- diversity: 1
# ----- Generating with seed: "eduler_active,
# 			   "synchronize_rcu_tasks called too soon");
#
#
# 	wai"
# eduler_active,
# 			   "synchronize_rcu_tasks called too soon");
#
#
# 	wait_rcu_head *head);
#
#
# ----- diversity: 1.5
# ----- Generating with seed: "eduler_active,
# 			   "synchronize_rcu_tasks called too soon");
#
#
# 	wai"
# eduler_active,
# 			   "synchronize_rcu_tasks called too soon");
#
#
# 	wait_rcu_head *head);
#
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 19350/19350 [==============================] - 68s - loss: 1.0290
#
# ----- diversity: 0.5
# ----- Generating with seed: "iffies;
# 			firstreport = true;
# 			warn_on(signal_pending(current));
# 		"
# iffies;
# 			firstreport = true;
# 			warn_on(signal_pending(current));
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void
#
# ----- diversity: 1
# ----- Generating with seed: "iffies;
# 			firstreport = true;
# 			warn_on(signal_pending(current));
# 		"
# iffies;
# 			firstreport = true;
# 			warn_on(signal_pending(current));
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void
#
# ----- diversity: 1.5
# ----- Generating with seed: "iffies;
# 			firstreport = true;
# 			warn_on(signal_pending(current));
# 		"
# iffies;
# 			firstreport = true;
# 			warn_on(signal_pending(current));
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void)
# {
# 	static struct teststack(&rcu_tesks_cbs_task(struct task(struct task struct *task(struct task t);
# 			if (rcu_tesks_coll_teststack(void
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 19350/19350 [==============================] - 67s - loss: 0.9307
#
# ----- diversity: 0.5
# ----- Generating with seed: "letion);
# }
#
# void wait_rcu_gp(call_rcu_func_t crf)
# {
# 	struct rcu_synchr"
# letion);
# }
#
# void wait_rcu_gp(call_rcu_func_t crf)
# {
# 	struct rcu_synchronize_rcu_tasks_kthread_mutex);
# 	if (rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_k
#
# ----- diversity: 1
# ----- Generating with seed: "letion);
# }
#
# void wait_rcu_gp(call_rcu_func_t crf)
# {
# 	struct rcu_synchr"
# letion);
# }
#
# void wait_rcu_gp(call_rcu_func_t crf)
# {
# 	struct rcu_synchronize_rcu_tasks_kthread_mutex);
# 	if (rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_k
#
# ----- diversity: 1.5
# ----- Generating with seed: "letion);
# }
#
# void wait_rcu_gp(call_rcu_func_t crf)
# {
# 	struct rcu_synchr"
# letion);
# }
#
# void wait_rcu_gp(call_rcu_func_t crf)
# {
# 	struct rcu_synchronize_rcu_tasks_kthread_mutex);
# 	if (rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_kthread_mutex);
# 		rcu_tasks_k
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 19350/19350 [==============================] - 347s - loss: 0.8565
#
# ----- diversity: 0.5
# ----- Generating with seed: ";
# }
#
# void rcu_sysrq_start(void)
# {
# 	if (!rcu_cpu_stall_suppress)
# 		rcu_"
# ;
# }
#
# void rcu_sysrq_start(void)
# {
# 	if (!rcu_cpu_stall_suppress)
# 		rcu_tasks_cbs_lock_in_evect(void)
# {
# 	static desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!
#
# ----- diversity: 1
# ----- Generating with seed: ";
# }
#
# void rcu_sysrq_start(void)
# {
# 	if (!rcu_cpu_stall_suppress)
# 		rcu_"
# ;
# }
#
# void rcu_sysrq_start(void)
# {
# 	if (!rcu_cpu_stall_suppress)
# 		rcu_tasks_cbs_lock_in_evect(void)
# {
# 	static desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!
#
# ----- diversity: 1.5
# ----- Generating with seed: ";
# }
#
# void rcu_sysrq_start(void)
# {
# 	if (!rcu_cpu_stall_suppress)
# 		rcu_"
# ;
# }
#
# void rcu_sysrq_start(void)
# {
# 	if (!rcu_cpu_stall_suppress)
# 		rcu_tasks_cbs_lock_in_evect(void)
# {
# 	static desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!desc->istate & irqs_autodetect;
# 			if (!
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 19350/19350 [==============================] - 72s - loss: 0.7927
#
# ----- diversity: 0.5
# ----- Generating with seed: "rt = false;
# 	}
# 	cpu = task_cpu(t);
# 	pr_alert("%p: %c%c nvcsw: %lu/%lu "
# rt = false;
# 	}
# 	cpu = task_cpu(t);
# 	pr_alert("%p: %c%c nvcsw: %lu/%lu holdout: %d idlest)
#
#
# ----- diversity: 1
# ----- Generating with seed: "rt = false;
# 	}
# 	cpu = task_cpu(t);
# 	pr_alert("%p: %c%c nvcsw: %lu/%lu "
# rt = false;
# 	}
# 	cpu = task_cpu(t);
# 	pr_alert("%p: %c%c nvcsw: %lu/%lu holdout: %d idlest)
#
#
# ----- diversity: 1.5
# ----- Generating with seed: "rt = false;
# 	}
# 	cpu = task_cpu(t);
# 	pr_alert("%p: %c%c nvcsw: %lu/%lu "
# rt = false;
# 	}
# 	cpu = task_cpu(t);
# 	pr_alert("%p: %c%c nvcsw: %lu/%lu holdout: %d idlest)
#
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 19350/19350 [==============================] - 71s - loss: 0.7507
#
# ----- diversity: 0.5
# ----- Generating with seed: "mmon
#
# #ifdef config_prove_rcu
# #define rcu_stall_delay_delta	       (5 "
# mmon
#
# #ifdef config_prove_rcu
# #define rcu_stall_delay_delta	       (5 * info = rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock,
#
# ----- diversity: 1
# ----- Generating with seed: "mmon
#
# #ifdef config_prove_rcu
# #define rcu_stall_delay_delta	       (5 "
# mmon
#
# #ifdef config_prove_rcu
# #define rcu_stall_delay_delta	       (5 * info = rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock,
#
# ----- diversity: 1.5
# ----- Generating with seed: "mmon
#
# #ifdef config_prove_rcu
# #define rcu_stall_delay_delta	       (5 "
# mmon
#
# #ifdef config_prove_rcu
# #define rcu_stall_delay_delta	       (5 * info = rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock, flags);
# 	}
# 		rcu_self_test_sched();
#
#
# void __gcov_merge_ior(&rcu_tasks_cbs_lock,
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 19350/19350 [==============================] - 71s - loss: 0.7120
#
# ----- diversity: 0.5
# ----- Generating with seed: "date."
#
# module_param(rcu_expedited, int, 0);
#
# #ifndef config_tiny_rcu
# "
# date."
#
# module_param(rcu_expedited, int, 0);
#
# #ifndef config_tiny_rcu
#
#
#
# void __rcu_self_test_counter);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (
#
# ----- diversity: 1
# ----- Generating with seed: "date."
#
# module_param(rcu_expedited, int, 0);
#
# #ifndef config_tiny_rcu
# "
# date."
#
# module_param(rcu_expedited, int, 0);
#
# #ifndef config_tiny_rcu
#
#
#
# void __rcu_self_test_counter);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (
#
# ----- diversity: 1.5
# ----- Generating with seed: "date."
#
# module_param(rcu_expedited, int, 0);
#
# #ifndef config_tiny_rcu
# "
# date."
#
# module_param(rcu_expedited, int, 0);
#
# #ifndef config_tiny_rcu
#
#
#
# void __rcu_self_test_counter);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (!rcu_stall_timeout_list);
# 		if (
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 19350/19350 [==============================] - 72s - loss: 0.6810
#
# ----- diversity: 0.5
# ----- Generating with seed: "if
#
#
# void rcu_end_inkernel_boot(void)
# {
# 	if (is_enabled(config_rcu_ex"
# if
#
#
# void rcu_end_inkernel_boot(void)
# {
# 	if (is_enabled(config_rcu_expedited || irq_found = 0;
# 	if (!rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &
#
# ----- diversity: 1
# ----- Generating with seed: "if
#
#
# void rcu_end_inkernel_boot(void)
# {
# 	if (is_enabled(config_rcu_ex"
# if
#
#
# void rcu_end_inkernel_boot(void)
# {
# 	if (is_enabled(config_rcu_expedited || irq_found = 0;
# 	if (!rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &
#
# ----- diversity: 1.5
# ----- Generating with seed: "if
#
#
# void rcu_end_inkernel_boot(void)
# {
# 	if (is_enabled(config_rcu_ex"
# if
#
#
# void rcu_end_inkernel_boot(void)
# {
# 	if (is_enabled(config_rcu_expedited || irq_found = 0;
# 	if (!rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &rcu_tasks_cbs_tail = &
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 19350/19350 [==============================] - 70s - loss: 0.6546
#
# ----- diversity: 0.5
# ----- Generating with seed: "lock_bh_held);
#
# #endif
#
#
# void wakeme_after_rcu(struct rcu_head *head)"
# lock_bh_held);
#
# #endif
#
#
# void wakeme_after_rcu(struct rcu_head *head)
# {
# 	int r_config_rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_h
#
# ----- diversity: 1
# ----- Generating with seed: "lock_bh_held);
#
# #endif
#
#
# void wakeme_after_rcu(struct rcu_head *head)"
# lock_bh_held);
#
# #endif
#
#
# void wakeme_after_rcu(struct rcu_head *head)
# {
# 	int r_config_rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_h
#
# ----- diversity: 1.5
# ----- Generating with seed: "lock_bh_held);
#
# #endif
#
#
# void wakeme_after_rcu(struct rcu_head *head)"
# lock_bh_held);
#
# #endif
#
#
# void wakeme_after_rcu(struct rcu_head *head)
# {
# 	int r_config_rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_head;
# 		rcu_tasks_cbs_h
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 19350/19350 [==============================] - 69s - loss: 0.6238
#
# ----- diversity: 0.5
# ----- Generating with seed: "e & irqs_waiting)) {
# 				desc->istate &= ~irqs_autodetect;
# 				irq_shu"
# e & irqs_waiting)) {
# 				desc->istate &= ~irqs_autodetect;
# 				irq_shutdown(desc);
# 			int restatic struct rcu_head *rhp, void *rcu_tasks_holdout, int, 0644);
#
# static int rcu_cpu_stall_selc_sched();
#
#
# 	for_each_irq_desc *desc) {
# 		raw_spin_lock_cpu(struct rcu_head *rhp,
#
#
# ----- diversity: 1
# ----- Generating with seed: "e & irqs_waiting)) {
# 				desc->istate &= ~irqs_autodetect;
# 				irq_shu"
# e & irqs_waiting)) {
# 				desc->istate &= ~irqs_autodetect;
# 				irq_shutdown(desc);
# 			int restatic struct rcu_head *rhp, void *rcu_tasks_holdout, int, 0644);
#
# static int rcu_cpu_stall_selc_sched();
#
#
# 	for_each_irq_desc *desc) {
# 		raw_spin_lock_cpu(struct rcu_head *rhp,
#
#
# ----- diversity: 1.5
# ----- Generating with seed: "e & irqs_waiting)) {
# 				desc->istate &= ~irqs_autodetect;
# 				irq_shu"
# e & irqs_waiting)) {
# 				desc->istate &= ~irqs_autodetect;
# 				irq_shutdown(desc);
# 			int restatic struct rcu_head *rhp, void *rcu_tasks_holdout, int, 0644);
#
# static int rcu_cpu_stall_selc_sched();
#
#
# 	for_each_irq_desc *desc) {
# 		raw_spin_lock_cpu(struct rcu_head *rhp,
#
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 19350/19350 [==============================] - 68s - loss: 0.6124
#
# ----- diversity: 0.5
# ----- Generating with seed: "_synchronize *rcu;
#
# 	rcu = container_of(head, struct rcu_synchronize, "
# _synchronize *rcu;
#
# 	rcu = container_of(head, struct rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_ca
#
# ----- diversity: 1
# ----- Generating with seed: "_synchronize *rcu;
#
# 	rcu = container_of(head, struct rcu_synchronize, "
# _synchronize *rcu;
#
# 	rcu = container_of(head, struct rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_ca
#
# ----- diversity: 1.5
# ----- Generating with seed: "_synchronize *rcu;
#
# 	rcu = container_of(head, struct rcu_synchronize, "
# _synchronize *rcu;
#
# 	rcu = container_of(head, struct rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_call_rcu_sched)
# {
# 	static struct rcu_head *head *rhp, void *rcu_tasks_kthread_mutex);
# 	rcu_read_lock_bh", &rcu_synchronize, fuls);
# 	return;
# 	}
# 	if (!rcu_self_test_bh) {
# 		early_boot_test_ca
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 19350/19350 [==============================] - 71s - loss: 0.5953
#
# ----- diversity: 0.5
# ----- Generating with seed: "ct task_struct *t = current;
#
# 	if (t->rcu_read_lock_nesting != 1) {
# 		"
# ct task_struct *t = current;
#
# 	if (t->rcu_read_lock_nesting != 1) {
# 		access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# stat
#
# ----- diversity: 1
# ----- Generating with seed: "ct task_struct *t = current;
#
# 	if (t->rcu_read_lock_nesting != 1) {
# 		"
# ct task_struct *t = current;
#
# 	if (t->rcu_read_lock_nesting != 1) {
# 		access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# stat
#
# ----- diversity: 1.5
# ----- Generating with seed: "ct task_struct *t = current;
#
# 	if (t->rcu_read_lock_nesting != 1) {
# 		"
# ct task_struct *t = current;
#
# 	if (t->rcu_read_lock_nesting != 1) {
# 		access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# static void rcu_self_test_sched = access_once(t->rcu_read_lock_map);
#
# static int rcu_self_test_counter++;
# 	bool rcu_self_test_sched)
# {
# 	static lock *addr;
# 	if (!debug_lockdep_map_init("rcu_read_lock_map);
#
# stat
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 19350/19350 [==============================] - 109s - loss: 0.5768
#
# ----- diversity: 0.5
# ----- Generating with seed: "mutex_unlock(&gcov_lock);
# }
#
# #ifdef config_modules
# static inline int w"
# mutex_unlock(&gcov_lock);
# }
#
# #ifdef config_modules
# static inline int within(void *rcu_tasks_holdout) = true;
# 			if (!rcu_self_test_sched)
# 		early_boot_test_call_rcu_sched();
# 			if (desc->istate & irqs_waiting);
#
#
# ----- diversity: 1
# ----- Generating with seed: "mutex_unlock(&gcov_lock);
# }
#
# #ifdef config_modules
# static inline int w"
# mutex_unlock(&gcov_lock);
# }
#
# #ifdef config_modules
# static inline int within(void *rcu_tasks_holdout) = true;
# 			if (!rcu_self_test_sched)
# 		early_boot_test_call_rcu_sched();
# 			if (desc->istate & irqs_waiting);
#
#
# ----- diversity: 1.5
# ----- Generating with seed: "mutex_unlock(&gcov_lock);
# }
#
# #ifdef config_modules
# static inline int w"
# mutex_unlock(&gcov_lock);
# }
#
# #ifdef config_modules
# static inline int within(void *rcu_tasks_holdout) = true;
# 			if (!rcu_self_test_sched)
# 		early_boot_test_call_rcu_sched();
# 			if (desc->istate & irqs_waiting);
#
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
#  9088/19350 [=============>................] - ETA: 56s - loss: 0.5386
